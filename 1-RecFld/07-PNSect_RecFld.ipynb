# %%
# %cd ..
# Out:
# /Users/xiruihan/Desktop/RecFldGrn-main

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Raw

# %%
import os 
import pandas as pd

RecName = 'PNSect'
folder = 'data/Simulations/'
raw_file_path =  os.path.join(folder, RecName) + '.csv'
print(raw_file_path)
# Out:
# data/Simulations/PNSect.csv

# %%
# load all records
df = pd.read_csv(raw_file_path)
df
# Out:
#     PID  ECID   PNID  PNSectID                           SectName
# 0    P0  EC21  72374       140         History of Present Illness
# 1    P0  EC21  72374       142                      Physical Exam
# 2    P0  EC21  72374       143                    Assessment/Plan
# 3    P0  EC21  72374       144               Patient Instructions
# 4    P0  EC21  72374       145  Problem List/Past Medical History
# ..   ..   ...    ...       ...                                ...
# 277  P7  EC17    435        44  Problem List/Past Medical History
# 278  P7  EC17    435        43                    Assessment/Plan
# 279  P7  EC17    435        42                      Physical Exam
# 280  P7  EC17    435        41                  Review of Systems
# 281  P7  EC17    435        40         History of Present Illness
#
# [282 rows x 5 columns]

# %%
df[df['PID'] == 'P5']
# Out:
#     PID  ECID  PNID  PNSectID                           SectName
# 243  P5  EC11   492        64                 Health Maintenance
# 244  P5  EC11   492        58  Problem List/Past Medical History
# 245  P5  EC11   492        61                          Allergies
# 246  P5  EC11   492        60                        Medications
# 247  P5  EC11   492        59         Procedure/Surgical History
# 248  P5  EC11   492        57               Patient Instructions
# 249  P5  EC11   492        56                    Assessment/Plan
# 250  P5  EC11   492        55                  Medicare Wellness
# 251  P5  EC11   492        54                      Physical Exam
# 252  P5  EC11   492        53                  Review of Systems
# 253  P5  EC11   492        52         History of Present Illness
# 254  P5  EC11   492        62                     Social History
# 255  P5  EC11   492        51                    Chief Complaint
# 256  P5  EC11   492        63                     Family History

# %% [markdown]
# ## Select Columns

# %%
parent_ids = ['PID','ECID','PNID']
focal_ids = ['PNSectID']


selected_cols = ['SectName']

df = df[parent_ids + focal_ids + selected_cols]
df
# Out:
#     PID  ECID   PNID  PNSectID                           SectName
# 0    P0  EC21  72374       140         History of Present Illness
# 1    P0  EC21  72374       142                      Physical Exam
# 2    P0  EC21  72374       143                    Assessment/Plan
# 3    P0  EC21  72374       144               Patient Instructions
# 4    P0  EC21  72374       145  Problem List/Past Medical History
# ..   ..   ...    ...       ...                                ...
# 277  P7  EC17    435        44  Problem List/Past Medical History
# 278  P7  EC17    435        43                    Assessment/Plan
# 279  P7  EC17    435        42                      Physical Exam
# 280  P7  EC17    435        41                  Review of Systems
# 281  P7  EC17    435        40         History of Present Illness
#
# [282 rows x 5 columns]

# %% [markdown]
# ## Basic Filtering

# %%
# nothing

# %% [markdown]
# ## DF Rec Raw

# %%
df_RecRaw = df
df_RecRaw
# Out:
# 0      72374
# 1      72374
# 2      72374
# 3      72374
# 4      72374
#        ...
# 277      435
# 278      435
# 279      435
# 280      435
# 281      435
# Name: PNID, Length: 282, dtype: object

# %% [markdown]
# # Fields in Records

# %%
df_RecRaw.columns
# Out:
# Index(['PID', 'ECID', 'PNID', 'PNSectID', 'SectName'], dtype='object')

# %%
df = df_RecRaw.copy()

for i in ['PID', 'ECID', 'PNID', 'PNSectID']:
    df[i] = df[i].astype(str)

# %% [markdown]
# ## Field: SectName

# %%
df['SectName']
# Out:
# 0             History of Present Illness
# 1                          Physical Exam
# 2                        Assessment/Plan
# 3                   Patient Instructions
# 4      Problem List/Past Medical History
#                      ...
# 277    Problem List/Past Medical History
# 278                      Assessment/Plan
# 279                        Physical Exam
# 280                    Review of Systems
# 281           History of Present Illness
# Name: SectName, Length: 282, dtype: object

# %% [markdown]
# ## Call Parents

# %%
def load_df_data_from_folder(data_folder, IDName):
    file_list = os.listdir(data_folder)
    # file_lis
    df = pd.concat([pd.read_pickle(os.path.join(data_folder, i)) for i in file_list if '.p' in i]).reset_index(drop = True)
    # df = df.sort_values(IDName).reset_index(drop = True)
    return df# .shape

fullrec_folder = 'data/ProcData/RecFolder/PN'
df_Pat = load_df_data_from_folder(fullrec_folder, 'PNID')[['PID','ECID','PNID']]
print(df_Pat.shape)
df_Pat.head()
# Out:
# (225, 3)
#   PID   ECID        PNID
# 0  P0   EC18       71800
# 1  P0  EC140  Missing1.0
# 2  P0   EC23  Missing2.0
# 3  P0  EC141  Missing3.0
# 4  P0  EC142  Missing4.0

# %%
for i in parent_ids + focal_ids:
    
    df[i] = df[i].astype(str)

# %%
df
# Out:
#     PID  ECID   PNID PNSectID                           SectName
# 0    P0  EC21  72374      140         History of Present Illness
# 1    P0  EC21  72374      142                      Physical Exam
# 2    P0  EC21  72374      143                    Assessment/Plan
# 3    P0  EC21  72374      144               Patient Instructions
# 4    P0  EC21  72374      145  Problem List/Past Medical History
# ..   ..   ...    ...      ...                                ...
# 277  P7  EC17    435       44  Problem List/Past Medical History
# 278  P7  EC17    435       43                    Assessment/Plan
# 279  P7  EC17    435       42                      Physical Exam
# 280  P7  EC17    435       41                  Review of Systems
# 281  P7  EC17    435       40         History of Present Illness
#
# [282 rows x 5 columns]

# %%
df = pd.merge(df_Pat, df, on = parent_ids, how = 'left')
df
# Out:
#     PID  ECID   PNID PNSectID                           SectName
# 0    P0  EC18  71800      190                 Health Maintenance
# 1    P0  EC18  71800      188                     Social History
# 2    P0  EC18  71800      178                    Chief Complaint
# 3    P0  EC18  71800      179         History of Present Illness
# 4    P0  EC18  71800      180                  Review of Systems
# ..   ..   ...    ...      ...                                ...
# 480  P7  EC17    435       44  Problem List/Past Medical History
# 481  P7  EC17    435       43                    Assessment/Plan
# 482  P7  EC17    435       42                      Physical Exam
# 483  P7  EC17    435       41                  Review of Systems
# 484  P7  EC17    435       40         History of Present Illness
#
# [485 rows x 5 columns]

# %%
import numpy as np

d = df
for col in focal_ids: 
    d.loc[d[col].isnull(), col] = ['Missing' + str(i) for i in np.ones(d[col].isnull().sum()).cumsum()]
    # d[col] = d[col].astype(int)
    assert len(d[col]) == d[col].nunique()
    
df = d
df
# Out:
#     PID  ECID   PNID PNSectID                           SectName
# 0    P0  EC18  71800      190                 Health Maintenance
# 1    P0  EC18  71800      188                     Social History
# 2    P0  EC18  71800      178                    Chief Complaint
# 3    P0  EC18  71800      179         History of Present Illness
# 4    P0  EC18  71800      180                  Review of Systems
# ..   ..   ...    ...      ...                                ...
# 480  P7  EC17    435       44  Problem List/Past Medical History
# 481  P7  EC17    435       43                    Assessment/Plan
# 482  P7  EC17    435       42                      Physical Exam
# 483  P7  EC17    435       41                  Review of Systems
# 484  P7  EC17    435       40         History of Present Illness
#
# [485 rows x 5 columns]

# %% [markdown]
# ## Pin Down

# %%
df_proc = df[['PID', 'ECID', 'PNID', 'PNSectID','SectName']]
df_proc
# Out:
#     PID  ECID   PNID PNSectID                           SectName
# 0    P0  EC18  71800      190                 Health Maintenance
# 1    P0  EC18  71800      188                     Social History
# 2    P0  EC18  71800      178                    Chief Complaint
# 3    P0  EC18  71800      179         History of Present Illness
# 4    P0  EC18  71800      180                  Review of Systems
# ..   ..   ...    ...      ...                                ...
# 480  P7  EC17    435       44  Problem List/Past Medical History
# 481  P7  EC17    435       43                    Assessment/Plan
# 482  P7  EC17    435       42                      Physical Exam
# 483  P7  EC17    435       41                  Review of Systems
# 484  P7  EC17    435       40         History of Present Illness
#
# [485 rows x 5 columns]

# %% [markdown]
# # Save and Load

# %% [markdown]
# ## Save

# %%
def convert_PID_to_PIDgroup(x, RANGE_SIZE):
    if type(x) == str:
        if 'P' in x:
            int_value = int(x.replace('P', ''))
    else:
        int_value = int(x)
    range_size = RANGE_SIZE
    group_idx = int(int_value / range_size)
    s = group_idx * range_size
    e = (group_idx + 1) * range_size - 1
    groupname = f'Group_s{s}_e{e}'
    return groupname

def write_df_to_folders(DataName, data_folder, df, IDname):
    dfy = df.copy()
    # data_folder = f'../Data/B-EHRDataSet/{DataName}'
    if not os.path.exists(data_folder):
        os.makedirs(data_folder)

    dfy['GroupName'] = dfy[IDname].apply(lambda x: convert_PID_to_PIDgroup(x , RANGE_SIZE))
    for groupname, dfx in dfy.groupby('GroupName'):
        file = os.path.join(data_folder, f'{groupname}.p')
        # print(file)
        dfx = dfx.drop(columns= ['GroupName'])
        dfx.to_pickle(file)
        
RANGE_SIZE = 10000

# %%
# the folder to save the Record.
###############
RecName = 'PNSect'
###############





rec_folder = 'data/ProcData/RecFolder'
IDname = 'PID' # always be PID, not review ID or other ID.

fullrec_folder = os.path.join(rec_folder, RecName)
print(fullrec_folder, '<----- fullrec_folder to save the records')
if not os.path.exists(fullrec_folder): os.makedirs(fullrec_folder)
# Out:
# data/ProcData/RecFolder/PNSect <----- fullrec_folder to save the records

# %%
df = df_proc

write_df_to_folders(RecName, fullrec_folder, df, IDname)

# %% [markdown]
# ## Load

# %%
def load_df_data_from_folder(data_folder, IDName):
    file_list = os.listdir(data_folder)
    # file_lis
    df = pd.concat([pd.read_pickle(os.path.join(data_folder, i)) for i in file_list if '.p' in i]).reset_index(drop = True)
    # df = df.sort_values(IDName).reset_index(drop = True)
    return df# .shape

# %%
IDName = 'PID'
print(fullrec_folder)
df = load_df_data_from_folder(fullrec_folder, IDName)
print(df.shape)
df.head()
df
# Out:
# data/ProcData/RecFolder/PNSect
# (485, 5)
#     PID  ECID   PNID PNSectID                           SectName
# 0    P0  EC18  71800      190                 Health Maintenance
# 1    P0  EC18  71800      188                     Social History
# 2    P0  EC18  71800      178                    Chief Complaint
# 3    P0  EC18  71800      179         History of Present Illness
# 4    P0  EC18  71800      180                  Review of Systems
# ..   ..   ...    ...      ...                                ...
# 480  P7  EC17    435       44  Problem List/Past Medical History
# 481  P7  EC17    435       43                    Assessment/Plan
# 482  P7  EC17    435       42                      Physical Exam
# 483  P7  EC17    435       41                  Review of Systems
# 484  P7  EC17    435       40         History of Present Illness
#
# [485 rows x 5 columns]

# %%
df[df['PID'] == 'P5']
# Out:
#     PID   ECID          PNID      PNSectID                           SectName
# 418  P5  EC129  Missing176.0  Missing176.0                                NaN
# 419  P5   EC76  Missing177.0  Missing177.0                                NaN
# 420  P5   EC99  Missing178.0  Missing178.0                                NaN
# 421  P5  EC100  Missing179.0  Missing179.0                                NaN
# 422  P5   EC96  Missing180.0  Missing180.0                                NaN
# 423  P5   EC97  Missing181.0  Missing181.0                                NaN
# 424  P5  EC103  Missing182.0  Missing182.0                                NaN
# 425  P5  EC104  Missing183.0  Missing183.0                                NaN
# 426  P5   EC11           492            64                 Health Maintenance
# 427  P5   EC11           492            58  Problem List/Past Medical History
# 428  P5   EC11           492            61                          Allergies
# 429  P5   EC11           492            60                        Medications
# 430  P5   EC11           492            59         Procedure/Surgical History
# 431  P5   EC11           492            57               Patient Instructions
# 432  P5   EC11           492            56                    Assessment/Plan
# 433  P5   EC11           492            55                  Medicare Wellness
# 434  P5   EC11           492            54                      Physical Exam
# 435  P5   EC11           492            53                  Review of Systems
# 436  P5   EC11           492            52         History of Present Illness
# 437  P5   EC11           492            62                     Social History
# 438  P5   EC11           492            51                    Chief Complaint
# 439  P5   EC11           492            63                     Family History
# 440  P5   EC90  Missing184.0  Missing184.0                                NaN
# 441  P5  EC105  Missing185.0  Missing185.0                                NaN
# 442  P5  EC133  Missing186.0  Missing186.0                                NaN
# 443  P5   EC94  Missing187.0  Missing187.0                                NaN
# 444  P5  EC134  Missing188.0  Missing188.0                                NaN
# 445  P5   EC60  Missing189.0  Missing189.0                                NaN
# 446  P5  EC137  Missing190.0  Missing190.0                                NaN
# 447  P5  EC205  Missing191.0  Missing191.0                                NaN
# 448  P5  EC198  Missing192.0  Missing192.0                                NaN
# 449  P5  EC135  Missing193.0  Missing193.0                                NaN
# 450  P5  EC138  Missing194.0  Missing194.0                                NaN
# 451  P5  EC206  Missing195.0  Missing195.0                                NaN
# 452  P5  EC200  Missing196.0  Missing196.0                                NaN
# 453  P5  EC199  Missing197.0  Missing197.0                                NaN

# %% [markdown]
# ## Load One Sample

# %%
def get_dfx_p_filename(IDValue, DataName, data_folder, RANGE_SIZE):
    group_name = convert_PID_to_PIDgroup(IDValue, RANGE_SIZE) 
    p_filename = f'{data_folder}/{DataName}/{group_name}.p'
    return p_filename
    
def load_patient_data(RID, IDValue, dfx):
    dfx = dfx[dfx[RID] == IDValue].reset_index(drop = True)
    return dfx

def get_dfx_from_buffer(RID, IDValue, DataName, data_folder, RANGE_SIZE, BUCKET_buffer):
    p_filename = get_dfx_p_filename(IDValue, DataName, data_folder, RANGE_SIZE)
    if p_filename not in BUCKET_buffer:
        dfx = pd.read_pickle(p_filename)
        BUCKET_buffer[p_filename] = dfx
        if len(BUCKET_buffer) > 100:
            for key in random.sample(BUCKET_buffer.keys(), 4):
                del BUCKET_buffer[key]
    else:
        dfx = BUCKET_buffer[p_filename]
    return dfx, BUCKET_buffer


class DataPoint(object):

    '''
    DataPoint: stands for one data point. 
    one instance is a patient.
    the instance of the patient could quickly the his/her record information by using `get_df_rec`.
    '''
    BUCKET_buffer = {}

    def __init__(self, RID, IDValue, data_folder, RANGE_SIZE):
        self.RID = RID
        self.IDValue = IDValue
        self.data_folder = data_folder
        self.df_rec_dict = {}
        self.RANGE_SIZE = RANGE_SIZE
        
    def get_df_rec(self, DataName):
        '''
        DataName: the name of the record, like: P, EC, BMI, PN, PNSect, etc.
        '''
        if DataName not in self.df_rec_dict:
            dfx, BUCKET_buffer = get_dfx_from_buffer(self.RID, self.IDValue, 
                                                     DataName, 
                                                     self.data_folder, 
                                                     self.RANGE_SIZE, 
                                                     self.BUCKET_buffer)
            self.BUCKET_buffer = BUCKET_buffer
            df_p = load_patient_data(self.RID, self.IDValue, dfx)
            self.df_rec_dict[DataName] = df_p
            return df_p
        else:
            return self.df_rec_dict[DataName]
        
    def __repr__(self):
        return f'<{self.RID} [{self.IDValue}]>'

# %%
# from recfldgrn.datapoint import PatientDP

# we want to study / explore P4 himself.

####################
RID = 'PID' # Record ID Name, always be PhyID
IDValue = 'P5'   # PhyID value
######################


data_folder = rec_folder
RANGE_SIZE = RANGE_SIZE

print(data_folder)


Pat = DataPoint(RID, IDValue, 
                data_folder, RANGE_SIZE)
Pat
# Out:
# data/ProcData/RecFolder
# <PID [P5]>

# %%
Pat.get_df_rec('PN')
# Out:
#    PID   ECID          PNID          DT
# 0   P5  EC129  Missing176.0         NaN
# 1   P5   EC76  Missing177.0         NaN
# 2   P5   EC99  Missing178.0         NaN
# 3   P5  EC100  Missing179.0         NaN
# 4   P5   EC96  Missing180.0         NaN
# 5   P5   EC97  Missing181.0         NaN
# 6   P5  EC103  Missing182.0         NaN
# 7   P5  EC104  Missing183.0         NaN
# 8   P5   EC11           492  2023-04-15
# 9   P5   EC90  Missing184.0         NaN
# 10  P5  EC105  Missing185.0         NaN
# 11  P5  EC133  Missing186.0         NaN
# 12  P5   EC94  Missing187.0         NaN
# 13  P5  EC134  Missing188.0         NaN
# 14  P5   EC60  Missing189.0         NaN
# 15  P5  EC137  Missing190.0         NaN
# 16  P5  EC205  Missing191.0         NaN
# 17  P5  EC198  Missing192.0         NaN
# 18  P5  EC135  Missing193.0         NaN
# 19  P5  EC138  Missing194.0         NaN
# 20  P5  EC206  Missing195.0         NaN
# 21  P5  EC200  Missing196.0         NaN
# 22  P5  EC199  Missing197.0         NaN

# %%
Pat.get_df_rec('PNSect')
# Out:
#    PID   ECID          PNID      PNSectID                           SectName
# 0   P5  EC129  Missing176.0  Missing176.0                                NaN
# 1   P5   EC76  Missing177.0  Missing177.0                                NaN
# 2   P5   EC99  Missing178.0  Missing178.0                                NaN
# 3   P5  EC100  Missing179.0  Missing179.0                                NaN
# 4   P5   EC96  Missing180.0  Missing180.0                                NaN
# 5   P5   EC97  Missing181.0  Missing181.0                                NaN
# 6   P5  EC103  Missing182.0  Missing182.0                                NaN
# 7   P5  EC104  Missing183.0  Missing183.0                                NaN
# 8   P5   EC11           492            64                 Health Maintenance
# 9   P5   EC11           492            58  Problem List/Past Medical History
# 10  P5   EC11           492            61                          Allergies
# 11  P5   EC11           492            60                        Medications
# 12  P5   EC11           492            59         Procedure/Surgical History
# 13  P5   EC11           492            57               Patient Instructions
# 14  P5   EC11           492            56                    Assessment/Plan
# 15  P5   EC11           492            55                  Medicare Wellness
# 16  P5   EC11           492            54                      Physical Exam
# 17  P5   EC11           492            53                  Review of Systems
# 18  P5   EC11           492            52         History of Present Illness
# 19  P5   EC11           492            62                     Social History
# 20  P5   EC11           492            51                    Chief Complaint
# 21  P5   EC11           492            63                     Family History
# 22  P5   EC90  Missing184.0  Missing184.0                                NaN
# 23  P5  EC105  Missing185.0  Missing185.0                                NaN
# 24  P5  EC133  Missing186.0  Missing186.0                                NaN
# 25  P5   EC94  Missing187.0  Missing187.0                                NaN
# 26  P5  EC134  Missing188.0  Missing188.0                                NaN
# 27  P5   EC60  Missing189.0  Missing189.0                                NaN
# 28  P5  EC137  Missing190.0  Missing190.0                                NaN
# 29  P5  EC205  Missing191.0  Missing191.0                                NaN
# 30  P5  EC198  Missing192.0  Missing192.0                                NaN
# 31  P5  EC135  Missing193.0  Missing193.0                                NaN
# 32  P5  EC138  Missing194.0  Missing194.0                                NaN
# 33  P5  EC206  Missing195.0  Missing195.0                                NaN
# 34  P5  EC200  Missing196.0  Missing196.0                                NaN
# 35  P5  EC199  Missing197.0  Missing197.0                                NaN

# %%
df_RecRaw[df_RecRaw['PID'] == 'P5']
# Out:
#     PID  ECID PNID  PNSectID                           SectName
# 243  P5  EC11  492        64                 Health Maintenance
# 244  P5  EC11  492        58  Problem List/Past Medical History
# 245  P5  EC11  492        61                          Allergies
# 246  P5  EC11  492        60                        Medications
# 247  P5  EC11  492        59         Procedure/Surgical History
# 248  P5  EC11  492        57               Patient Instructions
# 249  P5  EC11  492        56                    Assessment/Plan
# 250  P5  EC11  492        55                  Medicare Wellness
# 251  P5  EC11  492        54                      Physical Exam
# 252  P5  EC11  492        53                  Review of Systems
# 253  P5  EC11  492        52         History of Present Illness
# 254  P5  EC11  492        62                     Social History
# 255  P5  EC11  492        51                    Chief Complaint
# 256  P5  EC11  492        63                     Family History
