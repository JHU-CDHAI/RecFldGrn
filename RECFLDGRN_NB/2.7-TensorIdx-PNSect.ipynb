# %%
# %cd ..
# Out:
# /Users/floydluo/Library/CloudStorage/GoogleDrive-jjluo@terpmail.umd.edu/.shortcut-targets-by-id/1qNzMmGHCg5Xa63Vw3aKbZdMXvkfT2CgC/MedStar/MS_CODE/RecFldGrn

# %% [markdown]
# # Data Point

# %%
from recfldgrn.datapoint import PatientDP, RANGE_SIZE

PID = 'P4'
rec_folder = 'data/ProcData/RecFolder/'
Pat = PatientDP(PID, rec_folder, RANGE_SIZE)
Pat

# %%
####################
RecName = 'PNSect'
####################

df = Pat.get_df_rec(RecName)
df
# Out:
#    PID   ECID   PNID  PNSectID                           SectName
# 0   P4  EC125  72530       437                                NaN
# 1   P4   EC24  72531       438                                NaN
# 2   P4   EC36  72532       439                                NaN
# 3   P4   EC80  72533       440                                NaN
# 4   P4  EC163  72534       441                                NaN
# 5   P4  EC106  72535       442                                NaN
# 6   P4   EC85  72536       443                                NaN
# 7   P4   EC88  72537       444                                NaN
# 8   P4  EC179  72538       445                                NaN
# 9   P4   EC48  72539       446                                NaN
# 10  P4    EC7   1074        32  Problem List/Past Medical History
# 11  P4    EC7   1074        36                     Social History
# 12  P4    EC7   1074        35                          Allergies
# 13  P4    EC7   1074        34                        Medications
# 14  P4    EC7   1074        33         Procedure/Surgical History
# 15  P4    EC7   1074        31               Patient Instructions
# 16  P4    EC7   1074        30                    Assessment/Plan
# 17  P4    EC7   1074        29                      Physical Exam
# 18  P4    EC7   1074        28                  Review of Systems
# 19  P4    EC7   1074        27         History of Present Illness
# 20  P4    EC7   1074        26                    Chief Complaint
# 21  P4    EC7   1074        37                     Family History
# 22  P4    EC7   1074        38                 Health Maintenance
# 23  P4   EC70  72540       447                                NaN
# 24  P4   EC86  72541       448                                NaN
# 25  P4   EC10   1286        25                 Health Maintenance
# 26  P4   EC10   1286        23                     Social History
# 27  P4   EC10   1286        22                          Allergies
# 28  P4   EC10   1286        21                        Medications
# 29  P4   EC10   1286        20         Procedure/Surgical History
# 30  P4   EC10   1286        19  Problem List/Past Medical History
# 31  P4   EC10   1286        18               Patient Instructions
# 32  P4   EC10   1286        17                    Assessment/Plan
# 33  P4   EC10   1286        16                      Physical Exam
# 34  P4   EC10   1286        15                  Review of Systems
# 35  P4   EC10   1286        14         History of Present Illness
# 36  P4   EC10   1286        13                    Chief Complaint
# 37  P4   EC10   1286        24                     Family History
# 38  P4  EC130  72542       449                                NaN
# 39  P4  EC110  72543       450                                NaN
# 40  P4  EC202  72544       451                                NaN
# 41  P4  EC121  72545       452                                NaN
# 42  P4  EC196  72546       453                                NaN
# 43  P4  EC203  72547       454                                NaN
# 44  P4  EC204  72548       455                                NaN
# 45  P4  EC197  72549       456                                NaN

# %% [markdown]
# # Task Selection

# %%
TaskName = 'Task2YearXXX'

ELIG_PAT_SET = [f'P{i}' for i in range(0, 8)]
ELIG_PAT_SET
# Out:
# ['P0', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7']

# %%
import os
import pandas as pd

Tensor_folder = 'data/ProcData/TensorFolder'
TaskTensor_folder = os.path.join(Tensor_folder, TaskName)

if not os.path.exists(TaskTensor_folder): os.makedirs(TaskTensor_folder)

print(TaskTensor_folder)
# Out:
# data/ProcData/TensorFolder/Task2YearXXX

# %%
######################### Change this
RecName = 'PNSect'
######################### 


df = pd.DataFrame()
for PID in ELIG_PAT_SET:
    Pat = PatientDP(PID, rec_folder, RANGE_SIZE)
    dfx = Pat.get_df_rec(RecName)
    
    ###################################
    # TODO: make some operation to select good dfx
    dfx = dfx 
    ###################################
    
    df = pd.concat([df, dfx])
    
print(df.shape)
df
# Out:
# (485, 5)
#    PID  ECID   PNID  PNSectID                           SectName
# 0   P0  EC18  71800       190                 Health Maintenance
# 1   P0  EC18  71800       188                     Social History
# 2   P0  EC18  71800       178                    Chief Complaint
# 3   P0  EC18  71800       179         History of Present Illness
# 4   P0  EC18  71800       180                  Review of Systems
# ..  ..   ...    ...       ...                                ...
# 7   P7  EC17    435        44  Problem List/Past Medical History
# 8   P7  EC17    435        43                    Assessment/Plan
# 9   P7  EC17    435        42                      Physical Exam
# 10  P7  EC17    435        41                  Review of Systems
# 11  P7  EC17    435        40         History of Present Illness
#
# [485 rows x 5 columns]

# %% [markdown]
# # Load Meta Info

# %%
import os
import pandas as pd

fldgrn_folder = 'data/ProcData/FldGrnInfo'

fullfldgrn_file = os.path.join(fldgrn_folder, RecName + '.p')

df_FieldGrainInfo = pd.read_pickle(fullfldgrn_file)
df_FieldGrainInfo
# Out:
#   RecName         prefix_ids   focal_ids  field_list     field          grain  \
# 0  PNSect  [PID, ECID, PNID]  [PNSectID]  [SectName]  SectName  PNSctNmDftGrn
#
#               field2grain                 recfield2grain  \
# 0  SectName-PNSctNmDftGrn  PNSect@SectName-PNSctNmDftGrn
#
#                                                Vocab
# 0  {'idx2v': {0: '_padding', 1: '_missing', 2: 'P...

# %% [markdown]
# # RecFldGrn `PNSect@SectName-PNSctNmDftGrn`

# %%
from recfldgrn.grains import Field2Grain_2_get_GrnStrList_Fn
from recfldgrn.grains import Field2Grain_2_get_GrnIdxList_Fn
from recfldgrn.grains import Field2Grain_2_get_GrnWgtList_Fn
from recfldgrn.utils import generate_grain_vocab_info
from recfldgrn.utils import get_compressed_df
from recfldgrn.datapoint import write_df_to_folders

# %%
from recfldgrn.utils import get_highorder_input_idx

# %%
TaskTensor_folder
# Out:
# 'data/ProcData/TensorFolder/Task2YearXXX'

# %%
######################### Change this
recfield2grain = 'PNSect@SectName-PNSctNmDftGrn'
#########################

d = df_FieldGrainInfo[df_FieldGrainInfo['recfield2grain'] == recfield2grain].iloc[0]
v2idx = d['Vocab']['v2idx']
prefix_ids = d['prefix_ids']
focal_ids = d['focal_ids']

df_p = get_highorder_input_idx(df, recfield2grain, 
                               v2idx, prefix_ids, focal_ids,
                               Field2Grain_2_get_GrnIdxList_Fn, 
                               Field2Grain_2_get_GrnWgtList_Fn)



fullTaskTensor_folder = os.path.join(TaskTensor_folder, recfield2grain)
print(df.shape, fullTaskTensor_folder)
if not os.path.exists(fullTaskTensor_folder): os.makedirs(fullTaskTensor_folder)
write_df_to_folders(recfield2grain, fullTaskTensor_folder, df_p)

df_p
# Out:
# (485, 6) data/ProcData/TensorFolder/Task2YearXXX/PNSect@SectName-PNSctNmDftGrn
#   PID          P-EC-PN-PNSect@SectName-PNSctNmDftGrn_idx
# 0  P0  [[[[1]]], [[[1]]], [[[13], [14], [4], [16], [6...
# 1  P1  [[[[6], [16], [4], [14], [7, 8], [17], [18], [...
# 2  P2  [[[[1]]], [[[1]]], [[[1]]], [[[1]]], [[[1]]], ...
# 3  P3  [[[[6], [20], [7, 8], [17], [9], [10, 11], [2,...
# 4  P4  [[[[13], [12], [5], [9], [2, 3], [10, 11], [17...
# 5  P5  [[[[1]]], [[[1]]], [[[1]]], [[[1]]], [[[13], [...
# 6  P6  [[[[1]]], [[[1]]], [[[5], [9], [2, 3], [10, 11...
# 7  P7  [[[[14], [13], [15], [12], [5], [9], [2, 3], [...
